# %% [markdown]
# Improvement: read from API instead of csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta, MO

plt.rcParams["figure.figsize"]=20,20
url = "https://raw.githubusercontent.com/ChngYuanLongRandy/DataScience/main/median-rent-by-town-and-flat-type.csv"
url2 = "https://raw.githubusercontent.com/ChngYuanLongRandy/DataScience/main/gross-domestic-product-in-chained-2015-dollars-year-on-year-growth-rate-quarterly.csv"
#url = "https://data.gov.sg/api/action/datastore_search?resource_id=6b1ec2ff-7c38-4ce9-9bbb-af865b4d78cb"

#import json
#import requests
#response = requests.get(url)
#data = response.text


#a_json = json.loads(data)
#df = pd.DataFrame.from_dict(a_json, orient='index')
#df.reset_index(level=0, inplace=True)

#df = pd.DataFrame.from_dict(a_json)

#import urllib
#with urllib.request.urlopen(url) as response:
#print (response.read())


#url = "https://raw.githubusercontent.com/hashketh/hello-world/e6eb7ca3e5e1e1d2f1d7d9571966c396928bac76/candyhierarchy2017%20(1).csv"
#url = "https://github.com/ChngYuanLongRandy/DataScience/blob/main/Stats%20From%20Singstat.xlsx?raw=true"

# Reading the downloaded content and turning it into a pandas dataframe

#print (fileobj.read())
# , encoding="ISO-8859-1"

df = pd.read_csv(url, na_values='na', parse_dates=['quarter'])
df_gdp = pd.read_csv(url2)

# %%
df
# Out:
#          quarter        town flat_type median_rent
# 0     2005-04-01  ANG MO KIO      1-RM         NaN
# 1     2005-04-01  ANG MO KIO      2-RM         NaN
# 2     2005-04-01  ANG MO KIO      3-RM         800
# 3     2005-04-01  ANG MO KIO      4-RM         950
# 4     2005-04-01  ANG MO KIO      5-RM           -
# ...          ...         ...       ...         ...
# 10024 2021-01-01      YISHUN      2-RM           -
# 10025 2021-01-01      YISHUN      3-RM        1700
# 10026 2021-01-01      YISHUN      4-RM        1900
# 10027 2021-01-01      YISHUN      5-RM        2100
# 10028 2021-01-01      YISHUN      EXEC        2250
#
# [10029 rows x 4 columns]

# %%
df['quarter'] = pd.to_datetime(pd.to_datetime(df['quarter']).dt.strftime('%Y-%m'))
df['median_rent']=pd.to_numeric(df['median_rent'],errors='coerce')
df['flat_type'].astype('string')
df['town'].astype('string')
# Out:
# 0        ANG MO KIO
# 1        ANG MO KIO
# 2        ANG MO KIO
# 3        ANG MO KIO
# 4        ANG MO KIO
#             ...
# 10024        YISHUN
# 10025        YISHUN
# 10026        YISHUN
# 10027        YISHUN
# 10028        YISHUN
# Name: town, Length: 10029, dtype: string

# %%
df['quarter']
# Out:
# 0       2005-04-01
# 1       2005-04-01
# 2       2005-04-01
# 3       2005-04-01
# 4       2005-04-01
#            ...
# 10024   2021-01-01
# 10025   2021-01-01
# 10026   2021-01-01
# 10027   2021-01-01
# 10028   2021-01-01
# Name: quarter, Length: 10029, dtype: datetime64[ns]

# %% [markdown]
# We will create a dataframe called df_median to group

# %%
df_median = df.groupby(['quarter','town','flat_type']).median()

# %% [markdown]
# df_quarter_town with 2 index, quarter and town with median of all flat type as value

# %%
df_quarter_town=df.groupby(['quarter','town']).median()

# %%
df_quarter_flat_type=df.groupby(['quarter','flat_type']).median()

# %%
df
# Out:
#          quarter        town flat_type  median_rent
# 0     2005-04-01  ANG MO KIO      1-RM          NaN
# 1     2005-04-01  ANG MO KIO      2-RM          NaN
# 2     2005-04-01  ANG MO KIO      3-RM        800.0
# 3     2005-04-01  ANG MO KIO      4-RM        950.0
# 4     2005-04-01  ANG MO KIO      5-RM          NaN
# ...          ...         ...       ...          ...
# 10024 2021-01-01      YISHUN      2-RM          NaN
# 10025 2021-01-01      YISHUN      3-RM       1700.0
# 10026 2021-01-01      YISHUN      4-RM       1900.0
# 10027 2021-01-01      YISHUN      5-RM       2100.0
# 10028 2021-01-01      YISHUN      EXEC       2250.0
#
# [10029 rows x 4 columns]

# %%
df_median
# Out:
#                                  median_rent
# quarter    town       flat_type
# 2005-04-01 ANG MO KIO 1-RM               NaN
#                       2-RM               NaN
#                       3-RM             800.0
#                       4-RM             950.0
#                       5-RM               NaN
# ...                                      ...
# 2021-01-01 YISHUN     2-RM               NaN
#                       3-RM            1700.0
#                       4-RM            1900.0
#                       5-RM            2100.0
#                       EXEC            2250.0
#
# [10024 rows x 1 columns]

# %%
df_quarter_town
# Out:
#                         median_rent
# quarter    town
# 2005-04-01 ANG MO KIO         875.0
#            BEDOK              900.0
#            BISHAN            1050.0
#            BUKIT BATOK        835.0
#            BUKIT MERAH        850.0
# ...                             ...
# 2021-01-01 SERANGOON         2315.0
#            TAMPINES          2200.0
#            TOA PAYOH         2300.0
#            WOODLANDS         1875.0
#            YISHUN            2000.0
#
# [1672 rows x 1 columns]

# %%
df_quarter_town.unstack(level=0).median()
# Out:
#              quarter
# median_rent  2005-04-01     900.0
#              2005-07-01     900.0
#              2005-10-01     900.0
#              2006-01-01     875.0
#              2006-04-01     975.0
#                             ...
#              2020-01-01    2100.0
#              2020-04-01    2100.0
#              2020-07-01    2100.0
#              2020-10-01    2100.0
#              2021-01-01    2200.0
# Length: 64, dtype: float64

# %%
df_town_median = df_quarter_town.unstack(level=1).median()

# %%
quarter_dates = df.quarter.unique()
towns = df.town.unique()

# %%
df_quarter_town
# Out:
#                         median_rent
# quarter    town
# 2005-04-01 ANG MO KIO         875.0
#            BEDOK              900.0
#            BISHAN            1050.0
#            BUKIT BATOK        835.0
#            BUKIT MERAH        850.0
# ...                             ...
# 2021-01-01 SERANGOON         2315.0
#            TAMPINES          2200.0
#            TOA PAYOH         2300.0
#            WOODLANDS         1875.0
#            YISHUN            2000.0
#
# [1672 rows x 1 columns]

# %%
plt.plot(quarter_dates,df_quarter_town.unstack(level=0).median())
plt.xlabel("Quarter")
plt.ylabel('Median Rent in the year')
plt.title('Median Rent in Singapore over 15 years')
plt.show()

# %%
df_quarter_town.unstack(level=1).median()
# Out:
#              town
# median_rent  ANG MO KIO         2100.0
#              BEDOK              2125.0
#              BISHAN             2300.0
#              BUKIT BATOK        2000.0
#              BUKIT MERAH        2300.0
#              BUKIT PANJANG      1820.0
#              BUKIT TIMAH        1650.0
#              CENTRAL            2412.5
#              CHOA CHU KANG      1900.0
#              CLEMENTI           2325.0
#              GEYLANG            2250.0
#              HOUGANG            2000.0
#              JURONG EAST        2125.0
#              JURONG WEST        2087.5
#              KALLANG/WHAMPOA    2400.0
#              LIM CHU KANG          NaN
#              MARINE PARADE      1975.0
#              PASIR RIS          2100.0
#              PUNGGOL            1900.0
#              QUEENSTOWN         2245.0
#              SEMBAWANG          1945.0
#              SENGKANG           1950.0
#              SERANGOON          2200.0
#              TAMPINES           2100.0
#              TOA PAYOH          2300.0
#              WOODLANDS          1837.5
#              YISHUN             1900.0
# dtype: float64

# %%
plt.bar(towns,df_quarter_town.unstack(level=1).median())
plt.xlabel("Towns")
plt.ylabel('Median Rent in the year')
plt.title('Median Rent by Singapore Towns over 15 years')
plt.xticks(towns, fontsize=8 , rotation=90 )
plt.show()

# %% [markdown]
# df_median.loc[slice(None),'Lim Chu Kang']

# %%
df.groupby(by=["town",'flat_type'], dropna=True).median()
# Out:
#                       median_rent
# town       flat_type
# ANG MO KIO 1-RM               NaN
#            2-RM               NaN
#            3-RM            1700.0
#            4-RM            2100.0
#            5-RM            2400.0
# ...                           ...
# YISHUN     2-RM               NaN
#            3-RM            1600.0
#            4-RM            1825.0
#            5-RM            2000.0
#            EXEC            2300.0
#
# [162 rows x 1 columns]

# %%
df.groupby(by=["town",'flat_type'], dropna=True).median().unstack(level=1).plot()
# Out:
# <AxesSubplot:xlabel='town'>

# %%
df.index.names
# Out:
# FrozenList([None])

# %%
df['quarter']
# Out:
# 0       2005-04-01
# 1       2005-04-01
# 2       2005-04-01
# 3       2005-04-01
# 4       2005-04-01
#            ...
# 10024   2021-01-01
# 10025   2021-01-01
# 10026   2021-01-01
# 10027   2021-01-01
# 10028   2021-01-01
# Name: quarter, Length: 10029, dtype: datetime64[ns]

# %%
df_median.index.get_level_values(0)
# Out:
# DatetimeIndex(['2005-04-01', '2005-04-01', '2005-04-01', '2005-04-01',
#                '2005-04-01', '2005-04-01', '2005-04-01', '2005-04-01',
#                '2005-04-01', '2005-04-01',
#                ...
#                '2021-01-01', '2021-01-01', '2021-01-01', '2021-01-01',
#                '2021-01-01', '2021-01-01', '2021-01-01', '2021-01-01',
#                '2021-01-01', '2021-01-01'],
#               dtype='datetime64[ns]', name='quarter', length=10024, freq=None)

# %%
df_median.index.get_level_values(1)
# Out:
# Index(['ANG MO KIO', 'ANG MO KIO', 'ANG MO KIO', 'ANG MO KIO', 'ANG MO KIO',
#        'ANG MO KIO', 'BEDOK', 'BEDOK', 'BEDOK', 'BEDOK',
#        ...
#        'WOODLANDS', 'WOODLANDS', 'WOODLANDS', 'WOODLANDS', 'YISHUN', 'YISHUN',
#        'YISHUN', 'YISHUN', 'YISHUN', 'YISHUN'],
#       dtype='object', name='town', length=10024)

# %%
df_median.index.get_level_values(2)
# Out:
# Index(['1-RM', '2-RM', '3-RM', '4-RM', '5-RM', 'EXEC', '1-RM', '2-RM', '3-RM',
#        '4-RM',
#        ...
#        '3-RM', '4-RM', '5-RM', 'EXEC', '1-RM', '2-RM', '3-RM', '4-RM', '5-RM',
#        'EXEC'],
#       dtype='object', name='flat_type', length=10024)

# %%
df_median
# Out:
#                                  median_rent
# quarter    town       flat_type
# 2005-04-01 ANG MO KIO 1-RM               NaN
#                       2-RM               NaN
#                       3-RM             800.0
#                       4-RM             950.0
#                       5-RM               NaN
# ...                                      ...
# 2021-01-01 YISHUN     2-RM               NaN
#                       3-RM            1700.0
#                       4-RM            1900.0
#                       5-RM            2100.0
#                       EXEC            2250.0
#
# [10024 rows x 1 columns]

# %%
df_median.index.name = ('quarter','town','flat_type')

# %%
df_median
# Out:
#                                  median_rent
# quarter    town       flat_type
# 2005-04-01 ANG MO KIO 1-RM               NaN
#                       2-RM               NaN
#                       3-RM             800.0
#                       4-RM             950.0
#                       5-RM               NaN
# ...                                      ...
# 2021-01-01 YISHUN     2-RM               NaN
#                       3-RM            1700.0
#                       4-RM            1900.0
#                       5-RM            2100.0
#                       EXEC            2250.0
#
# [10024 rows x 1 columns]

# %%
isinstance(df_median.index, pd.MultiIndex)
# Out:
# True

# %%
df_median.index.name
# Out:
# ('quarter', 'town', 'flat_type')

# %%
df_median.loc[slice(None),'LIM CHU KANG', slice(None)]
# Out:
#                       median_rent
# quarter    flat_type
# 2005-04-01 1-RM               NaN
#            2-RM               NaN
#            3-RM               NaN
#            4-RM               NaN
#            5-RM               NaN
#            EXEC               NaN
# 2005-07-01 1-RM               NaN
#            2-RM               NaN
#            3-RM               NaN
#            4-RM               NaN
#            5-RM               NaN
#            EXEC               NaN
# 2005-10-01 1-RM               NaN
#            2-RM               NaN
#            3-RM               NaN
#            4-RM               NaN
#            5-RM               NaN
#            EXEC               NaN
# 2006-01-01 1-RM               NaN
#            2-RM               NaN
#            3-RM               NaN
#            4-RM               NaN
#            5-RM               NaN
#            EXEC               NaN
# 2006-04-01 1-RM               NaN
#            2-RM               NaN
#            3-RM               NaN
#            4-RM               NaN
#            5-RM               NaN
#            EXEC               NaN
# 2006-07-01 1-RM               NaN
#            2-RM               NaN
#            3-RM               NaN
#            4-RM               NaN
#            5-RM               NaN
#            EXEC               NaN
# 2006-10-01 1-RM               NaN
#            2-RM               NaN
#            3-RM               NaN
#            4-RM               NaN
#            5-RM               NaN
#            EXEC               NaN
# 2007-01-01 1-RM               NaN
#            2-RM               NaN
#            3-RM               NaN
#            4-RM               NaN
#            5-RM               NaN
#            EXEC               NaN
# 2007-04-01 1-RM               NaN
#            2-RM               NaN
#            3-RM               NaN
#            4-RM               NaN
#            5-RM               NaN
#            EXEC               NaN

# %%
df_median.loc['2010-01-01','YISHUN','3-RM']
# Out:
# median_rent    1350.0
# Name: (2010-01-01 00:00:00, YISHUN, 3-RM), dtype: float64

# %%
df_median.loc['2010-01-01',slice(None),'3-RM']
# Out:
#                                       median_rent
# quarter    town            flat_type
# 2010-01-01 ANG MO KIO      3-RM            1450.0
#            BEDOK           3-RM            1500.0
#            BISHAN          3-RM            1470.0
#            BUKIT BATOK     3-RM            1400.0
#            BUKIT MERAH     3-RM            1600.0
#            BUKIT PANJANG   3-RM            1280.0
#            BUKIT TIMAH     3-RM               NaN
#            CENTRAL         3-RM            1900.0
#            CHOA CHU KANG   3-RM               NaN
#            CLEMENTI        3-RM            1550.0
#            GEYLANG         3-RM            1400.0
#            HOUGANG         3-RM            1380.0
#            JURONG EAST     3-RM            1400.0
#            JURONG WEST     3-RM            1330.0
#            KALLANG/WHAMPOA 3-RM            1500.0
#            MARINE PARADE   3-RM            1640.0
#            PASIR RIS       3-RM               NaN
#            PUNGGOL         3-RM               NaN
#            QUEENSTOWN      3-RM            1600.0
#            SEMBAWANG       3-RM               NaN
#            SENGKANG        3-RM               NaN
#            SERANGOON       3-RM            1480.0
#            TAMPINES        3-RM            1550.0
#            TOA PAYOH       3-RM            1500.0
#            WOODLANDS       3-RM            1300.0
#            YISHUN          3-RM            1350.0

# %%
df_median.loc['2010-01-01',slice(None),'3-RM'].median()
# Out:
# median_rent    1475.0
# dtype: float64

# %%
df_median.loc[slice(None),slice(None),'3-RM']
# Out:
#                         median_rent
# quarter    town
# 2005-04-01 ANG MO KIO         800.0
#            BEDOK              800.0
#            BISHAN               NaN
#            BUKIT BATOK        745.0
#            BUKIT MERAH        850.0
# ...                             ...
# 2021-01-01 SERANGOON         1850.0
#            TAMPINES          1800.0
#            TOA PAYOH         1850.0
#            WOODLANDS         1500.0
#            YISHUN            1700.0
#
# [1671 rows x 1 columns]

# %%
df_median.loc[slice(None),slice(None),'3-RM'].median()
# Out:
# median_rent    1730.0
# dtype: float64

# %%
df_median.loc[slice(None),slice(None),slice(None)].median()
# Out:
# median_rent    2000.0
# dtype: float64

# %%
df_median.loc[slice(None),slice(None)].median()
# Out:
# median_rent    2000.0
# dtype: float64

# %%
df_median.loc[slice(None),slice(None),'3-RM']
# Out:
#                         median_rent
# quarter    town
# 2005-04-01 ANG MO KIO         800.0
#            BEDOK              800.0
#            BISHAN               NaN
#            BUKIT BATOK        745.0
#            BUKIT MERAH        850.0
# ...                             ...
# 2021-01-01 SERANGOON         1850.0
#            TAMPINES          1800.0
#            TOA PAYOH         1850.0
#            WOODLANDS         1500.0
#            YISHUN            1700.0
#
# [1671 rows x 1 columns]

# %%
df_median.loc['2009',slice(None)].median()
# Out:
# median_rent    1700.0
# dtype: float64

# %%
df['quarter']
# Out:
# 0       2005-04-01
# 1       2005-04-01
# 2       2005-04-01
# 3       2005-04-01
# 4       2005-04-01
#            ...
# 10024   2021-01-01
# 10025   2021-01-01
# 10026   2021-01-01
# 10027   2021-01-01
# 10028   2021-01-01
# Name: quarter, Length: 10029, dtype: datetime64[ns]

# %% [markdown]
# plt.plot(df['quarter'],df_median)

# %%
df_quarter= df['quarter']
df_town=df['town']
df_flat_type= ("1-RM","2-RM","3-RM","4-RM","5-RM","EXEC")
df_median_rent = df['median_rent']

# %% [markdown]
# df['median_rent'] = pd.to_numeric(df['median_rent'], errors = 'coerce')

# %%
df_amk = df[df['town']=='ANG MO KIO']

df_amk_3RM = df_amk[df_amk['flat_type']=='3-RM']
df_amk_3RM_time = df_amk_3RM['quarter']

df_amk_3RM_time
df_amk_1RM = df_amk[df_amk['flat_type']=='1-RM']
df_amk_1RM_time = df_amk_1RM['quarter']
                             
df_amk_2RM = df_amk[df_amk['flat_type']=='2-RM']
df_amk_2RM_time = df_amk_2RM['quarter']
                             
df_amk_5RM = df_amk[df_amk['flat_type']=='5-RM']
df_amk_5RM_time = df_amk_5RM['quarter']

df_amk_EXEC = df_amk[df_amk['flat_type']=='EXEC']
df_amk_EXEC_time = df_amk_EXEC['quarter']

# %%
df_amk_2RM['median_rent'].isna().count()
# Out:
# 63

# %%
df_amk_2RM['median_rent'].count()
# Out:
# 0

# %%
plt.plot(df_amk_1RM_time,df_amk_1RM['median_rent'],color ='m', alpha = 0.8)
plt.plot(df_amk_2RM_time,df_amk_2RM['median_rent'],color ='c', alpha = 0.8)
plt.plot(df_amk_3RM_time,df_amk_3RM['median_rent'], color ='red', alpha = 0.8)
plt.plot(df_amk_5RM_time,df_amk_5RM['median_rent'],color ='blue', alpha = 0.8)
plt.plot(df_amk_EXEC_time,df_amk_EXEC['median_rent'],color ='green', alpha = 0.8)
plt.xlabel("Quarter")
plt.ylabel("Median Rent for AMK 3 RM")
plt.legend(["AMK 1-RM","AMK 2-RM","AMK 3-RM", "AMK 5-RM",'AMK EXEC'])
plt.show()

# %%
def shows_plot_for_town (town):
    df_amk = df[df['town']== town]

    df_amk_3RM = df_amk[df_amk['flat_type']=='3-RM']
    df_amk_3RM_time = df_amk_3RM['quarter']

    df_amk_3RM_time
    df_amk_1RM = df_amk[df_amk['flat_type']=='1-RM']
    df_amk_1RM_time = df_amk_1RM['quarter']

    df_amk_2RM = df_amk[df_amk['flat_type']=='2-RM']
    df_amk_2RM_time = df_amk_2RM['quarter']

    df_amk_5RM = df_amk[df_amk['flat_type']=='5-RM']
    df_amk_5RM_time = df_amk_5RM['quarter']

    df_amk_EXEC = df_amk[df_amk['flat_type']=='EXEC']
    df_amk_EXEC_time = df_amk_EXEC['quarter']
    
    plt.plot(df_amk_1RM_time,df_amk_1RM['median_rent'],color ='m', alpha = 0.8)
    plt.plot(df_amk_2RM_time,df_amk_2RM['median_rent'],color ='c', alpha = 0.8)
    plt.plot(df_amk_3RM_time,df_amk_3RM['median_rent'], color ='red', alpha = 0.8)
    plt.plot(df_amk_5RM_time,df_amk_5RM['median_rent'],color ='blue', alpha = 0.8)
    plt.plot(df_amk_EXEC_time,df_amk_EXEC['median_rent'],color ='green', alpha = 0.8)
    plt.xlabel("Quarter")
    plt.ylabel("Median Rent for " + town + " 3 RM")
    plt.legend(["1-RM","2-RM","3-RM", "5-RM",'EXEC'])
    plt.show()

# %%
shows_plot_for_town("YISHUN")

# %%
shows_plot_for_town("WOODLANDS")

# %% [markdown]
# For the below I want to know the change over the years for each town regardless of flat type

# %%
df_quarter_town.unstack(level=1).plot(title = "Rents of Individual Singapore Town over 15 years")
# Out:
# <AxesSubplot:title={'center':'Rents of Individual Singapore Town over 15 years'}, xlabel='quarter'>

# %%
df_quarter_flat_type.unstack(level=1).plot(title = "Median Rent of Singapore over 15 years by flat type")
# Out:
# <AxesSubplot:title={'center':'Median Rent of Singapore over 15 years by flat type'}, xlabel='quarter'>

# %% [markdown]
# for i to len(town):
#     df_loop_town = df[df['town']== town[i]]
#     df_loop_rent = df[df_loop_town[]]
#     df_amk_3RM = df_amk[df_amk['flat_type']=='3-RM']
#     df_amk_3RM_time = df_amk_3RM['quarter']
#
#     df_amk_1RM = df_amk[df_amk['flat_type']=='1-RM']
#     df_amk_1RM_time = df_amk_1RM['quarter']
#
#     df_amk_2RM = df_amk[df_amk['flat_type']=='2-RM']
#     df_amk_2RM_time = df_amk_2RM['quarter']
#
#     df_amk_5RM = df_amk[df_amk['flat_type']=='5-RM']
#     df_amk_5RM_time = df_amk_5RM['quarter']
#
#     df_amk_EXEC = df_amk[df_amk['flat_type']=='EXEC']
#     df_amk_EXEC_time = df_amk_EXEC['quarter']
#
#     plt.plot(df_amk_1RM_time,df_amk_1RM['median_rent'],color ='m', alpha = 0.8)

# %%
df_1RM = df[df['flat_type']=='1-RM']
df_1RM_time = df_1RM['quarter']

df_2RM = df[df['flat_type']=='2-RM']
df_2RM_time = df_2RM['quarter']

df_3RM = df[df['flat_type']=='3-RM']
df_3RM_time = df_3RM['quarter']

df_5RM = df[df['flat_type']=='5-RM']
df_5RM_time = df_5RM['quarter']


df_EXEC = df[df['flat_type']=='EXEC']
df_EXEC_time = df_EXEC['quarter']


plt.plot(df_1RM_time,df_1RM['median_rent'],color ='m', alpha = 0.5)
plt.plot(df_2RM_time,df_2RM['median_rent'],color ='c', alpha = 0.5)
plt.plot(df_3RM_time,df_3RM['median_rent'], color ='red', alpha = 0.5)
plt.plot(df_5RM_time,df_5RM['median_rent'],color ='blue', alpha = 0.5)
plt.plot(df_EXEC_time,df_EXEC['median_rent'],color ='green', alpha = 0.5)
plt.xlabel("Quarter")
plt.ylabel("Median Rent")
plt.legend(["1-RM","2-RM","3-RM", "5-RM",'EXEC'])
plt.show()

# %% [markdown]
# df_flattype = df.groupby(['median_rent','flat_type'])['Median_rent_for_flattype'].transform('median')

# %% [markdown]
# I think most probably the missing numbers is because those types of flats are not present in the town

# %%
df['town'].value_counts()
# Out:
# BISHAN             386
# CLEMENTI           384
# GEYLANG            384
# TOA PAYOH          384
# BUKIT PANJANG      384
# MARINE PARADE      384
# SERANGOON          384
# SEMBAWANG          384
# JURONG EAST        384
# BUKIT MERAH        384
# JURONG WEST        384
# QUEENSTOWN         384
# CHOA CHU KANG      384
# WOODLANDS          384
# PUNGGOL            384
# KALLANG/WHAMPOA    384
# PASIR RIS          384
# TAMPINES           384
# SENGKANG           384
# YISHUN             384
# HOUGANG            384
# BUKIT TIMAH        384
# CENTRAL            383
# BEDOK              382
# BUKIT BATOK        382
# ANG MO KIO         378
# LIM CHU KANG        54
# Name: town, dtype: int64

# %% [markdown]
# I want to plot the trend for AMK flats across all flat types. then afterwards

# %%
df_quarter= df['quarter']
df_town=df['town']
df_flat_type=df['flat_type']

# %%
df_quarter
# Out:
# 0       2005-04-01
# 1       2005-04-01
# 2       2005-04-01
# 3       2005-04-01
# 4       2005-04-01
#            ...
# 10024   2021-01-01
# 10025   2021-01-01
# 10026   2021-01-01
# 10027   2021-01-01
# 10028   2021-01-01
# Name: quarter, Length: 10029, dtype: datetime64[ns]

# %%
df_town=df['town']
df_flat_type=df['flat_type']

# %%
df_flat_type
# Out:
# 0        1-RM
# 1        2-RM
# 2        3-RM
# 3        4-RM
# 4        5-RM
#          ...
# 10024    2-RM
# 10025    3-RM
# 10026    4-RM
# 10027    5-RM
# 10028    EXEC
# Name: flat_type, Length: 10029, dtype: object

# %%
df_town
# Out:
# 0        ANG MO KIO
# 1        ANG MO KIO
# 2        ANG MO KIO
# 3        ANG MO KIO
# 4        ANG MO KIO
#             ...
# 10024        YISHUN
# 10025        YISHUN
# 10026        YISHUN
# 10027        YISHUN
# 10028        YISHUN
# Name: town, Length: 10029, dtype: object

# %% [markdown]
# df_town[df_quarter == '2005']

# %% [markdown]
# df.index.names

# %% [markdown]
# df.set_index(pd.DatetimeIndex(df['quarter']), inplace=True)

# %% [markdown]
# df.index.names

# %% [markdown]
# df

# %% [markdown]
# df.set_index(df_town, df_flat_type,inplace = True)

# %% [markdown]
# df

# %% [markdown]
# df.index.name

# %% [markdown]
# df.set_index(['quarter', 'town', 'flat_type'], inplace=True)

# %% [markdown]
# df

# %% [markdown]
# df.index.names

# %% [markdown]
# df.index.get_level_values(0)

# %% [markdown]
# df.index.get_level_values(1)

# %% [markdown]
# df.index.get_level_values(2)

# %% [markdown]
# df.sort_index()

# %% [markdown]
# df.iloc[2]

# %% [markdown]
# df.iloc[2,0]

# %% [markdown]
# df.iloc[4]

# %% [markdown]
# df

# %% [markdown]
# df.index.lexsort_depth

# %% [markdown]
# df.index.names

# %% [markdown]
# df.sort_index

# %% [markdown]
# df.groupby[['quarter', 'town','flat_type']].median_rent.median()

# %%
df_gdp
# Out:
#      quarter                        level_1  value
# 0    1976-Q1  GDP In Chained (2015) Dollars    8.2
# 1    1976-Q2  GDP In Chained (2015) Dollars    7.4
# 2    1976-Q3  GDP In Chained (2015) Dollars    7.2
# 3    1976-Q4  GDP In Chained (2015) Dollars    7.0
# 4    1977-Q1  GDP In Chained (2015) Dollars    6.2
# ..       ...                            ...    ...
# 173  2019-Q2  GDP In Chained (2015) Dollars    0.2
# 174  2019-Q3  GDP In Chained (2015) Dollars    0.7
# 175  2019-Q4  GDP In Chained (2015) Dollars    1.0
# 176  2020-Q1  GDP In Chained (2015) Dollars   -0.3
# 177  2020-Q2  GDP In Chained (2015) Dollars  -13.2
#
# [178 rows x 3 columns]

# %%
df_gdp.head()
# Out:
#    quarter                        level_1  value
# 0  1976-Q1  GDP In Chained (2015) Dollars    8.2
# 1  1976-Q2  GDP In Chained (2015) Dollars    7.4
# 2  1976-Q3  GDP In Chained (2015) Dollars    7.2
# 3  1976-Q4  GDP In Chained (2015) Dollars    7.0
# 4  1977-Q1  GDP In Chained (2015) Dollars    6.2

# %%
df_gdp.tail()
# Out:
#      quarter                        level_1  value
# 173  2019-Q2  GDP In Chained (2015) Dollars    0.2
# 174  2019-Q3  GDP In Chained (2015) Dollars    0.7
# 175  2019-Q4  GDP In Chained (2015) Dollars    1.0
# 176  2020-Q1  GDP In Chained (2015) Dollars   -0.3
# 177  2020-Q2  GDP In Chained (2015) Dollars  -13.2

# %%
df_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   quarter  178 non-null    object
#  1   level_1  178 non-null    object
#  2   value    178 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 4.3+ KB

# %%
df_gdp.describe()
# Out:
#             value
# count  178.000000
# mean     6.342135
# std      4.594405
# min    -13.200000
# 25%      4.125000
# 50%      7.050000
# 75%      9.500000
# max     18.600000

# %%
df_gdp.shape
# Out:
# (178, 3)

# %%
df_gdp['value']=pd.to_numeric(df_gdp['value'])
df_gdp['quarter']=pd.to_datetime((pd.to_datetime(df_gdp['quarter']).dt.to_period('Q').dt.end_time).dt.strftime('%Y-%m'))

# %%
df_gdp
# Out:
#        quarter                        level_1  value
# 0   1976-03-01  GDP In Chained (2015) Dollars    8.2
# 1   1976-06-01  GDP In Chained (2015) Dollars    7.4
# 2   1976-09-01  GDP In Chained (2015) Dollars    7.2
# 3   1976-12-01  GDP In Chained (2015) Dollars    7.0
# 4   1977-03-01  GDP In Chained (2015) Dollars    6.2
# ..         ...                            ...    ...
# 173 2019-06-01  GDP In Chained (2015) Dollars    0.2
# 174 2019-09-01  GDP In Chained (2015) Dollars    0.7
# 175 2019-12-01  GDP In Chained (2015) Dollars    1.0
# 176 2020-03-01  GDP In Chained (2015) Dollars   -0.3
# 177 2020-06-01  GDP In Chained (2015) Dollars  -13.2
#
# [178 rows x 3 columns]

# %%
df_gdp['quarter']
# Out:
# 0     1976-03-01
# 1     1976-06-01
# 2     1976-09-01
# 3     1976-12-01
# 4     1977-03-01
#          ...
# 173   2019-06-01
# 174   2019-09-01
# 175   2019-12-01
# 176   2020-03-01
# 177   2020-06-01
# Name: quarter, Length: 178, dtype: datetime64[ns]

# %%
df_gdp['quarter'][df_gdp['quarter'] >= '2015']
# Out:
# 156   2015-03-01
# 157   2015-06-01
# 158   2015-09-01
# 159   2015-12-01
# 160   2016-03-01
# 161   2016-06-01
# 162   2016-09-01
# 163   2016-12-01
# 164   2017-03-01
# 165   2017-06-01
# 166   2017-09-01
# 167   2017-12-01
# 168   2018-03-01
# 169   2018-06-01
# 170   2018-09-01
# 171   2018-12-01
# 172   2019-03-01
# 173   2019-06-01
# 174   2019-09-01
# 175   2019-12-01
# 176   2020-03-01
# 177   2020-06-01
# Name: quarter, dtype: datetime64[ns]

# %%
df_gdp['value'][df_gdp['quarter'] >= '2015']
# Out:
# 156     3.0
# 157     3.1
# 158     3.7
# 159     2.2
# 160     3.1
# 161     2.7
# 162     2.7
# 163     4.4
# 164     4.3
# 165     3.4
# 166     5.1
# 167     4.5
# 168     4.8
# 169     4.9
# 170     3.0
# 171     1.1
# 172     1.0
# 173     0.2
# 174     0.7
# 175     1.0
# 176    -0.3
# 177   -13.2
# Name: value, dtype: float64

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(quarter_dates,df_quarter_town.unstack(level=0).median(), 'g-')
ax2.plot(df_gdp['quarter'][df_gdp['quarter'] >= '2005'],df_gdp['value'][df_gdp['quarter'] >= '2005'], 'b-')

#plt.plot(quarter_dates,df_quarter_town.unstack(level=0).median())
#plt.plot(df_gdp['quarter'],df_gdp['value'])
#plt.xlabel("Quarter")
#plt.ylabel('Median Rent in the year')

ax1.set_xlabel("Quarter")
ax1.set_ylabel('Median Rent in the year', color='g')
ax2.set_ylabel('GDP in 2015 $', color='b')

plt.title('Median Rent in Singapore over 15 years VS GDP')
plt.show()

# %%
df_quarter_town.unstack(level=0).median()
# Out:
#              quarter
# median_rent  2005-04-01     900.0
#              2005-07-01     900.0
#              2005-10-01     900.0
#              2006-01-01     875.0
#              2006-04-01     975.0
#                             ...
#              2020-01-01    2100.0
#              2020-04-01    2100.0
#              2020-07-01    2100.0
#              2020-10-01    2100.0
#              2021-01-01    2200.0
# Length: 64, dtype: float64

# %%
df_onlyquarter= df.groupby(['quarter']).median()

# %%
df_onlyquarter
# Out:
#             median_rent
# quarter
# 2005-04-01        900.0
# 2005-07-01        900.0
# 2005-10-01        900.0
# 2006-01-01        900.0
# 2006-04-01       1000.0
# ...                 ...
# 2020-01-01       2000.0
# 2020-04-01       2000.0
# 2020-07-01       2000.0
# 2020-10-01       2000.0
# 2021-01-01       2100.0
#
# [64 rows x 1 columns]

# %%
df_gdp
# Out:
#        quarter                        level_1  value
# 0   1976-03-01  GDP In Chained (2015) Dollars    8.2
# 1   1976-06-01  GDP In Chained (2015) Dollars    7.4
# 2   1976-09-01  GDP In Chained (2015) Dollars    7.2
# 3   1976-12-01  GDP In Chained (2015) Dollars    7.0
# 4   1977-03-01  GDP In Chained (2015) Dollars    6.2
# ..         ...                            ...    ...
# 173 2019-06-01  GDP In Chained (2015) Dollars    0.2
# 174 2019-09-01  GDP In Chained (2015) Dollars    0.7
# 175 2019-12-01  GDP In Chained (2015) Dollars    1.0
# 176 2020-03-01  GDP In Chained (2015) Dollars   -0.3
# 177 2020-06-01  GDP In Chained (2015) Dollars  -13.2
#
# [178 rows x 3 columns]

# %%
datesample = pd.date_range('1976-04-01','2020-07-01', freq='3MS').strftime("%Y-%m").tolist()

# %%
datesample = pd.to_datetime(datesample)

# %%
datesample
# Out:
# DatetimeIndex(['1976-04-01', '1976-07-01', '1976-10-01', '1977-01-01',
#                '1977-04-01', '1977-07-01', '1977-10-01', '1978-01-01',
#                '1978-04-01', '1978-07-01',
#                ...
#                '2018-04-01', '2018-07-01', '2018-10-01', '2019-01-01',
#                '2019-04-01', '2019-07-01', '2019-10-01', '2020-01-01',
#                '2020-04-01', '2020-07-01'],
#               dtype='datetime64[ns]', length=178, freq=None)

# %% [markdown]
# df_gdp['quarter'] = df_gdp['quarter'] + datetime.timedelta(weeks=+4)

# %%
df_gdp['quarter'] = datesample

# %%
df_gdp
# Out:
#        quarter                        level_1  value
# 0   1976-04-01  GDP In Chained (2015) Dollars    8.2
# 1   1976-07-01  GDP In Chained (2015) Dollars    7.4
# 2   1976-10-01  GDP In Chained (2015) Dollars    7.2
# 3   1977-01-01  GDP In Chained (2015) Dollars    7.0
# 4   1977-04-01  GDP In Chained (2015) Dollars    6.2
# ..         ...                            ...    ...
# 173 2019-07-01  GDP In Chained (2015) Dollars    0.2
# 174 2019-10-01  GDP In Chained (2015) Dollars    0.7
# 175 2020-01-01  GDP In Chained (2015) Dollars    1.0
# 176 2020-04-01  GDP In Chained (2015) Dollars   -0.3
# 177 2020-07-01  GDP In Chained (2015) Dollars  -13.2
#
# [178 rows x 3 columns]

# %%
df_gdp_premerge = df_gdp.set_index('quarter')

# %%
df_gdp_premerge
# Out:
#                                   level_1  value
# quarter
# 1976-04-01  GDP In Chained (2015) Dollars    8.2
# 1976-07-01  GDP In Chained (2015) Dollars    7.4
# 1976-10-01  GDP In Chained (2015) Dollars    7.2
# 1977-01-01  GDP In Chained (2015) Dollars    7.0
# 1977-04-01  GDP In Chained (2015) Dollars    6.2
# ...                                   ...    ...
# 2019-07-01  GDP In Chained (2015) Dollars    0.2
# 2019-10-01  GDP In Chained (2015) Dollars    0.7
# 2020-01-01  GDP In Chained (2015) Dollars    1.0
# 2020-04-01  GDP In Chained (2015) Dollars   -0.3
# 2020-07-01  GDP In Chained (2015) Dollars  -13.2
#
# [178 rows x 2 columns]

# %%
df_combine = df_onlyquarter.join(df_gdp_premerge, how='inner')

# %%
df_combine.corr()
# Out:
#              median_rent     value
# median_rent     1.000000 -0.253563
# value          -0.253563  1.000000
